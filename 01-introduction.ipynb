# %% [markdown]
# # Session 01: Introduction to Computer Vision
#
# **CVI4IC - Summer Semester 2026**
#
# In this notebook, we'll set up our environment and get a first taste of working with images using OpenCV and Python.

# %% [markdown]
# ## 1. Environment Setup
#
# First, let's install and import the required packages.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
from pathlib import Path

print(f"OpenCV version: {cv2.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# OpenCV version: 4.13.0
# NumPy version: 2.4.2

# %% [markdown]
# ## 2. Datasets
#
# Throughout this course we use two main datasets:
#
# 1. **Fruits-360** — 174,700 images of 251 fruit/vegetable classes (100×100 px). Used for exercises in sessions 01-12.
# 2. **BAMBI** — Aerial wildlife monitoring imagery for the student project. Contains drone flights with annotations for roe deer, red deer, wild boar, and more.

# %% [markdown]
# ### 2.1 Fruits-360
#
# The [Fruits-360](https://github.com/fruits-360/) dataset contains 174,700 images of 251 classes (fruits, vegetables, nuts, seeds), all 100×100 px. It is organized into `Training/` and `Test/` splits by class name.

# %%
# Clone the Fruits-360 dataset (shallow clone to save time)
# !git clone --depth 1 https://github.com/fruits-360/fruits-360-100x100.git 2>/dev/null || echo "Dataset already cloned."

# Set dataset root
DATASET_ROOT = Path("fruits-360-100x100")
TRAIN_DIR = DATASET_ROOT / "Training"
TEST_DIR = DATASET_ROOT / "Test"

# List available classes
classes = sorted(os.listdir(TRAIN_DIR))
print(f"\nFruits-360: {len(classes)} classes found")
print(f"First 10 classes: {classes[:10]}")
# Out:
# Fruits-360: 251 classes found
# First 10 classes: ['Almonds 1', 'Apple 10', 'Apple 11', 'Apple 12', 'Apple 13', 'Apple 14', 'Apple 17', 'Apple 18', 'Apple 19', 'Apple 20']

# %% [markdown]
# ### 2.2 BAMBI — Aerial Wildlife Monitoring (Project Dataset)
#
# The [BAMBI](https://github.com/bambi-eco/Dataset) dataset contains drone imagery for wildlife monitoring. You will use this dataset for your **course project**.
#
# **Download steps:**
# 1. Clone the dataset repository (contains metadata and download scripts)
# 2. Filter flights by species of interest (e.g., roe deer, red deer, wild boar)
# 3. Download the selected flights from Zenodo using the provided script
# 4. Extract the downloaded zip files
# 5. Extract thermal frames from the downloaded flight videos
#
# > The `-f` flag specifies which flight IDs to download. Adjust the species filter and flight IDs to match your project needs.

# %%
# Step 1: Clone the BAMBI dataset repository
# !git clone https://github.com/bambi-eco/Dataset.git 2>/dev/null || echo "BAMBI repo already cloned."

# Step 2: Filter flights by species of interest
# !python Dataset/filter_flights.py --folder Dataset/flight_metadata/ --species "Roe deer" "Red deer" "Wild boar"

# Step 3: Download selected flights from Zenodo
# -f specifies flight IDs to download (e.g., 0 1 2)
# !python Dataset/download_from_zenodo.py \
    -s Dataset/flight_metadata/zenodo_upload_summary.json \
    -f 0 1

# Step 4: Extract the downloaded zip files
import glob
for zf in sorted(glob.glob("bambi_downloads/**/*.zip", recursive=True)):
    print(f"Extracting {zf} ...")
    # !unzip -q -o "{zf}" -d bambi_downloads/

# Step 5: Extract thermal frames from downloaded flight videos
# --no-rgb skips RGB frames and only extracts thermal images
# !python Dataset/frame_extraction.py bambi_downloads exported_frames --no-rgb
# Out:
# ============================================================
# Applied filters:
# ------------------------------------------------------------
#   Species:    Roe deer, Red deer, Wild boar  (OR, substring match)
# ============================================================
#
# ['0', '100', '101', '102', '103', '104', '105', '106', '10', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '129', '130', '131', '132', '134', '135', '136', '137', '138', '139', '13', '140', '141', '142', '143', '144', '145', '146', '147', '148', '149', '14', '150', '151', '152', '155', '156', '158', '159', '15', '160', '161', '162', '163', '16', '175', '176', '177', '178', '179', '17', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '18', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '1', '200', '201', '202', '203', '204', '205', '206', '207', '209', '20', '210', '211', '212', '213', '215', '216', '21', '221', '222', '223', '224', '225', '226', '227', '228', '229', '22', '230', '231', '232', '234', '235', '236', '237', '238', '239', '240', '241', '242', '243', '244', '245', '246', '247', '248', '249', '250', '251', '252', '256', '259', '260', '261', '262', '263', '264', '265', '266', '267', '26', '276', '277', '278', '279', '27', '280', '281', '282', '283', '284', '28', '294', '295', '296', '297', '298', '299', '29', '2', '300', '301', '302', '303', '304', '305', '306', '307', '308', '309', '30', '314', '31', '32', '33', '343', '344', '345', '346', '347', '348', '349', '34', '35', '367', '368', '369', '36', '370', '371', '372', '373', '374', '375', '376', '377', '378', '379', '37', '380', '381', '382', '383', '384', '385', '386', '387', '388', '389', '390', '391', '392', '393', '394', '395', '3', '40', '41', '42', '44', '45', '46', '47', '48', '50', '52', '53', '54', '55', '56', '57', '59', '64', '66', '67', '6', '70', '71', '72', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '89', '92', '93', '94', '95', '96', '98', '99']
#
# 266 / 386 flights matched.
#
# 📥 Downloading 2 flight(s) from 1 deposition(s)
#
# ──────────────────────────────────────────────────
#   Part 1 (deposition 18692354)
#   ⬇  flight_0.zip
#      577.7 / 577.7 MB (100%)
#   ⬇  flight_1.zip
#      778.1 / 778.1 MB (100%)
#
# ──────────────────────────────────────────────────
# ✅ Done! Downloaded: 2, Skipped: 0
#    Files saved to /workspaces/cvi4ic-notebooks/bambi_downloads
# Extracting bambi_downloads/flight_0.zip ...
# Extracting bambi_downloads/flight_1.zip ...
# Found 2 video(s):
#
#   [0] 0_matched_processed.mp4  <->  0_gt.txt
#   [1] 1_matched_processed.mp4  <->  1_gt.txt
#
#   Video: 0_matched_processed.mp4
#   ID: 0  MOT: 0_gt.txt
#   Resolution: 2048x1024 (each half: 1024x1024)
#   Total frames: 9840, FPS: 29.97
#   Frame range: 0 to end (exclusive)
#   Sample rate: every 1 frame(s)
#   Naming: 0_<frame_idx>.png
#     Exported 100 frames (frame index 99)...
#     Exported 200 frames (frame index 199)...
#     Exported 300 frames (frame index 299)...
#     Exported 400 frames (frame index 399)...
#     Exported 500 frames (frame index 499)...
#     Exported 600 frames (frame index 599)...
#     Exported 700 frames (frame index 699)...
#     Exported 800 frames (frame index 799)...
#     Exported 900 frames (frame index 899)...
#     Exported 1000 frames (frame index 999)...
#     Exported 1100 frames (frame index 1099)...
#     Exported 1200 frames (frame index 1199)...
#     Exported 1300 frames (frame index 1299)...
#     Exported 1400 frames (frame index 1399)...
#     Exported 1500 frames (frame index 1499)...
#     Exported 1600 frames (frame index 1599)...
#     Exported 1700 frames (frame index 1699)...
#     Exported 1800 frames (frame index 1799)...
#     Exported 1900 frames (frame index 1899)...
#     Exported 2000 frames (frame index 1999)...
#     Exported 2100 frames (frame index 2099)...
#     Exported 2200 frames (frame index 2199)...
#     Exported 2300 frames (frame index 2299)...
#     Exported 2400 frames (frame index 2399)...
#     Exported 2500 frames (frame index 2499)...
#     Exported 2600 frames (frame index 2599)...
#     Exported 2700 frames (frame index 2699)...
#     Exported 2800 frames (frame index 2799)...
#     Exported 2900 frames (frame index 2899)...
#     Exported 3000 frames (frame index 2999)...
#     Exported 3100 frames (frame index 3099)...
#     Exported 3200 frames (frame index 3199)...
#     Exported 3300 frames (frame index 3299)...
#     Exported 3400 frames (frame index 3399)...
#     Exported 3500 frames (frame index 3499)...
#     Exported 3600 frames (frame index 3599)...
#     Exported 3700 frames (frame index 3699)...
#     Exported 3800 frames (frame index 3799)...
#     Exported 3900 frames (frame index 3899)...
#     Exported 4000 frames (frame index 3999)...
#     Exported 4100 frames (frame index 4099)...
#     Exported 4200 frames (frame index 4199)...
#     Exported 4300 frames (frame index 4299)...
#     Exported 4400 frames (frame index 4399)...
#     Exported 4500 frames (frame index 4499)...
#     Exported 4600 frames (frame index 4599)...
#     Exported 4700 frames (frame index 4699)...
#     Exported 4800 frames (frame index 4799)...
#     Exported 4900 frames (frame index 4899)...
#     Exported 5000 frames (frame index 4999)...
#     Exported 5100 frames (frame index 5099)...
#     Exported 5200 frames (frame index 5199)...
#     Exported 5300 frames (frame index 5299)...
#     Exported 5400 frames (frame index 5399)...
#     Exported 5500 frames (frame index 5499)...
#     Exported 5600 frames (frame index 5599)...
#     Exported 5700 frames (frame index 5699)...
#     Exported 5800 frames (frame index 5799)...
#     Exported 5900 frames (frame index 5899)...
#     Exported 6000 frames (frame index 5999)...
#     Exported 6100 frames (frame index 6099)...
#     Exported 6200 frames (frame index 6199)...
#     Exported 6300 frames (frame index 6299)...
#     Exported 6400 frames (frame index 6399)...
#     Exported 6500 frames (frame index 6499)...
#     Exported 6600 frames (frame index 6599)...
#     Exported 6700 frames (frame index 6699)...
#     Exported 6800 frames (frame index 6799)...
#     Exported 6900 frames (frame index 6899)...
#     Exported 7000 frames (frame index 6999)...
#     Exported 7100 frames (frame index 7099)...
#     Exported 7200 frames (frame index 7199)...
#     Exported 7300 frames (frame index 7299)...
#     Exported 7400 frames (frame index 7399)...
#     Exported 7500 frames (frame index 7499)...
#     Exported 7600 frames (frame index 7599)...
#     Exported 7700 frames (frame index 7699)...
#     Exported 7800 frames (frame index 7799)...
#     Exported 7900 frames (frame index 7899)...
#     Exported 8000 frames (frame index 7999)...
#     Exported 8100 frames (frame index 8099)...
#     Exported 8200 frames (frame index 8199)...
#     Exported 8300 frames (frame index 8299)...
#     Exported 8400 frames (frame index 8399)...
#     Exported 8500 frames (frame index 8499)...
#     Exported 8600 frames (frame index 8599)...
#     Exported 8700 frames (frame index 8699)...
#     Exported 8800 frames (frame index 8799)...
#     Exported 8900 frames (frame index 8899)...
#     Exported 9000 frames (frame index 8999)...
#     Exported 9100 frames (frame index 9099)...
#     Exported 9200 frames (frame index 9199)...
#     Exported 9300 frames (frame index 9299)...
#     Exported 9400 frames (frame index 9399)...
#     Exported 9500 frames (frame index 9499)...
#     Exported 9600 frames (frame index 9599)...
#     Exported 9700 frames (frame index 9699)...
#     Exported 9800 frames (frame index 9799)...
#   MOT: 107 annotations -> 0_gt.txt
#   Done: 9840 frames exported.
#
#   Video: 1_matched_processed.mp4
#   ID: 1  MOT: 1_gt.txt
#   Resolution: 2048x1024 (each half: 1024x1024)
#   Total frames: 12150, FPS: 29.97
#   Frame range: 0 to end (exclusive)
#   Sample rate: every 1 frame(s)
#   Naming: 1_<frame_idx>.png
#     Exported 100 frames (frame index 99)...
#     Exported 200 frames (frame index 199)...
#     Exported 300 frames (frame index 299)...
#     Exported 400 frames (frame index 399)...
#     Exported 500 frames (frame index 499)...
#     Exported 600 frames (frame index 599)...
#     Exported 700 frames (frame index 699)...
#     Exported 800 frames (frame index 799)...
#     Exported 900 frames (frame index 899)...
#     Exported 1000 frames (frame index 999)...
#     Exported 1100 frames (frame index 1099)...
#     Exported 1200 frames (frame index 1199)...
#     Exported 1300 frames (frame index 1299)...
#     Exported 1400 frames (frame index 1399)...
#     Exported 1500 frames (frame index 1499)...
#     Exported 1600 frames (frame index 1599)...
#     Exported 1700 frames (frame index 1699)...
#     Exported 1800 frames (frame index 1799)...
#     Exported 1900 frames (frame index 1899)...
#     Exported 2000 frames (frame index 1999)...
#     Exported 2100 frames (frame index 2099)...
#     Exported 2200 frames (frame index 2199)...
#     Exported 2300 frames (frame index 2299)...
#     Exported 2400 frames (frame index 2399)...
#     Exported 2500 frames (frame index 2499)...
#     Exported 2600 frames (frame index 2599)...
#     Exported 2700 frames (frame index 2699)...
#     Exported 2800 frames (frame index 2799)...
#     Exported 2900 frames (frame index 2899)...
#     Exported 3000 frames (frame index 2999)...
#     Exported 3100 frames (frame index 3099)...
#     Exported 3200 frames (frame index 3199)...
#     Exported 3300 frames (frame index 3299)...
#     Exported 3400 frames (frame index 3399)...
#     Exported 3500 frames (frame index 3499)...
#     Exported 3600 frames (frame index 3599)...
#     Exported 3700 frames (frame index 3699)...
#     Exported 3800 frames (frame index 3799)...
#     Exported 3900 frames (frame index 3899)...
#     Exported 4000 frames (frame index 3999)...
#     Exported 4100 frames (frame index 4099)...
#     Exported 4200 frames (frame index 4199)...
#     Exported 4300 frames (frame index 4299)...
#     Exported 4400 frames (frame index 4399)...
#     Exported 4500 frames (frame index 4499)...
#     Exported 4600 frames (frame index 4599)...
#     Exported 4700 frames (frame index 4699)...
#     Exported 4800 frames (frame index 4799)...
#     Exported 4900 frames (frame index 4899)...
#     Exported 5000 frames (frame index 4999)...
#     Exported 5100 frames (frame index 5099)...
#     Exported 5200 frames (frame index 5199)...
#     Exported 5300 frames (frame index 5299)...
#     Exported 5400 frames (frame index 5399)...
#     Exported 5500 frames (frame index 5499)...
#     Exported 5600 frames (frame index 5599)...
#     Exported 5700 frames (frame index 5699)...
#     Exported 5800 frames (frame index 5799)...
#     Exported 5900 frames (frame index 5899)...
#     Exported 6000 frames (frame index 5999)...
#     Exported 6100 frames (frame index 6099)...
#     Exported 6200 frames (frame index 6199)...
#     Exported 6300 frames (frame index 6299)...
#     Exported 6400 frames (frame index 6399)...
#     Exported 6500 frames (frame index 6499)...
#     Exported 6600 frames (frame index 6599)...
#     Exported 6700 frames (frame index 6699)...
#     Exported 6800 frames (frame index 6799)...
#     Exported 6900 frames (frame index 6899)...
#     Exported 7000 frames (frame index 6999)...
#     Exported 7100 frames (frame index 7099)...
#     Exported 7200 frames (frame index 7199)...
#     Exported 7300 frames (frame index 7299)...
#     Exported 7400 frames (frame index 7399)...
#     Exported 7500 frames (frame index 7499)...
#     Exported 7600 frames (frame index 7599)...
#     Exported 7700 frames (frame index 7699)...
#     Exported 7800 frames (frame index 7799)...
#     Exported 7900 frames (frame index 7899)...
#     Exported 8000 frames (frame index 7999)...
#     Exported 8100 frames (frame index 8099)...
#     Exported 8200 frames (frame index 8199)...
#     Exported 8300 frames (frame index 8299)...
#     Exported 8400 frames (frame index 8399)...
#     Exported 8500 frames (frame index 8499)...
#     Exported 8600 frames (frame index 8599)...
#     Exported 8700 frames (frame index 8699)...
#     Exported 8800 frames (frame index 8799)...
#     Exported 8900 frames (frame index 8899)...
#     Exported 9000 frames (frame index 8999)...
#     Exported 9100 frames (frame index 9099)...
#     Exported 9200 frames (frame index 9199)...
#     Exported 9300 frames (frame index 9299)...
#     Exported 9400 frames (frame index 9399)...
#     Exported 9500 frames (frame index 9499)...
#     Exported 9600 frames (frame index 9599)...
#     Exported 9700 frames (frame index 9699)...
#     Exported 9800 frames (frame index 9799)...
#     Exported 9900 frames (frame index 9899)...
#     Exported 10000 frames (frame index 9999)...
#     Exported 10100 frames (frame index 10099)...
#     Exported 10200 frames (frame index 10199)...
#     Exported 10300 frames (frame index 10299)...
#     Exported 10400 frames (frame index 10399)...
#     Exported 10500 frames (frame index 10499)...
#     Exported 10600 frames (frame index 10599)...
#     Exported 10700 frames (frame index 10699)...
#     Exported 10800 frames (frame index 10799)...
#     Exported 10900 frames (frame index 10899)...
#     Exported 11000 frames (frame index 10999)...
#     Exported 11100 frames (frame index 11099)...
#     Exported 11200 frames (frame index 11199)...
#     Exported 11300 frames (frame index 11299)...
#     Exported 11400 frames (frame index 11399)...
#     Exported 11500 frames (frame index 11499)...
#     Exported 11600 frames (frame index 11599)...
#     Exported 11700 frames (frame index 11699)...
#     Exported 11800 frames (frame index 11799)...
#     Exported 11900 frames (frame index 11899)...
#     Exported 12000 frames (frame index 11999)...
#     Exported 12100 frames (frame index 12099)...
#   MOT: 235 annotations -> 1_gt.txt
#   Done: 12150 frames exported.
#
# All done. 21990 frames exported from 2 video(s).

# %% [markdown]
# ### 2.3 BAMBI — ALFS Data
#
# The ALFS (Airborne Light Field Sampling) subset of BAMBI contains pre-rendered **thermal** detection images from nadir UAV recordings of forest wildlife. This is a single ~5 GB download — no flight filtering needed.
#
# Zenodo DOI: [10.5281/zenodo.18772136](https://doi.org/10.5281/zenodo.18772136)
#
# > **Important:** Frames from a single flight are very similar. When creating train/test splits, split by **flight** (not by frame) to avoid data leakage!

# %%
# Download ALFS dataset from Zenodo (~5 GB)
# !wget -q --show-progress https://zenodo.org/api/records/18772136/files/dataset.zip/content -O alfs_dataset.zip
# !unzip -q alfs_dataset.zip -d alfs_data/
# Out:
# alfs_dataset.zip    100%[===================>]   4.95G  14.0MB/s    in 7m 23s

# %% [markdown]
# ## 3. Loading and Displaying Images
#
# Let's load some fruit images from the dataset and explore their properties.

# %%
# Load a fruit image
apple_dir = TRAIN_DIR / "Apple Red 1"
img_path = sorted(apple_dir.glob("*.jpg"))[0]
img = cv2.imread(str(img_path))

print(f"Image path: {img_path.name}")
print(f"Image shape: {img.shape}  (height, width, channels)")
print(f"Image dtype: {img.dtype}")
print(f"Pixel value range: [{img.min()}, {img.max()}]")
# Out:
# Image path: 0_100.jpg
# Image shape: (100, 100, 3)  (height, width, channels)
# Image dtype: uint8
# Pixel value range: [7, 255]

# %%
# Display with matplotlib (OpenCV loads as BGR — convert to RGB)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(4, 4))
plt.imshow(img_rgb)
plt.title(f"Apple Red 1 — {img.shape[1]}×{img.shape[0]} px")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
# Display a grid of different fruit classes
sample_classes = ["Apple Red 1", "Banana 1", "Cherry 1", "Lemon 1", "Orange 1", "Strawberry 1", "Tomato 1", "Pear 1"]
fig, axes = plt.subplots(2, 4, figsize=(12, 6))

for ax, cls_name in zip(axes.flat, sample_classes):
    cls_dir = TRAIN_DIR / cls_name
    img_path = sorted(cls_dir.glob("*.jpg"))[0]
    img = cv2.imread(str(img_path))
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    ax.imshow(img_rgb)
    ax.set_title(cls_name, fontsize=10)
    ax.axis("off")

plt.suptitle("Fruits-360 — Sample Classes", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Basic Image Operations

# %%
# Access individual pixel values (center of the 100x100 image)
pixel = img[50, 50]
print(f"Pixel at (50, 50): B={pixel[0]}, G={pixel[1]}, R={pixel[2]}")

# Crop a region (the fruit is centered in the image)
crop = img[20:80, 20:80]
print(f"Cropped region shape: {crop.shape}")

# Resize to a larger image
resized = cv2.resize(img, (256, 256))
print(f"Resized shape: {resized.shape}")

# Show original, cropped, and resized side by side
fig, axes = plt.subplots(1, 3, figsize=(10, 4))
axes[0].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
axes[0].set_title(f"Original ({img.shape[1]}×{img.shape[0]})")
axes[1].imshow(cv2.cvtColor(crop, cv2.COLOR_BGR2RGB))
axes[1].set_title(f"Cropped ({crop.shape[1]}×{crop.shape[0]})")
axes[2].imshow(cv2.cvtColor(resized, cv2.COLOR_BGR2RGB))
axes[2].set_title(f"Resized ({resized.shape[1]}×{resized.shape[0]})")
for ax in axes:
    ax.axis("off")
plt.tight_layout()
plt.show()
# Out:
# Pixel at (50, 50): B=96, G=168, R=186
# Cropped region shape: (60, 60, 3)
# Resized shape: (256, 256, 3)

# %% [markdown]
# ## 5. Drawing on Images

# %%
# Draw bounding boxes and labels on a fruit image
img_draw = cv2.resize(img.copy(), (256, 256))

# Simulate a detection bounding box around the fruit
cv2.rectangle(img_draw, (40, 40), (216, 216), (0, 255, 0), 2)
cv2.putText(img_draw, "Apple", (40, 35), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

# Draw a circle at the center
cv2.circle(img_draw, (128, 128), 5, (0, 0, 255), -1)

plt.figure(figsize=(5, 5))
plt.imshow(cv2.cvtColor(img_draw, cv2.COLOR_BGR2RGB))
plt.title("Drawing on Images: Bounding Box & Label")
plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exercises
#
# 1. **Explore the dataset:** Pick 3 fruit classes of your choice, load one image from each, and display them side by side. Print the number of images per class.
# 2. **Grid overlay:** Write a function `draw_grid(img, step=10)` that draws a grid overlay on any image. Test it on a fruit image.
# 3. **Resize comparison:** Load a fruit image and resize it to 32×32 using `cv2.INTER_NEAREST`, `cv2.INTER_LINEAR`, and `cv2.INTER_CUBIC`. Display all three results scaled back up to 256×256 — can you see the difference?

# %%
# Your code here
